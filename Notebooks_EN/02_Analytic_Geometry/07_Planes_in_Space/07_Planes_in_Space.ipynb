# %% [markdown]
# # 07_Planes_in_Space

# %% [markdown]
# ## Tasks related to equations of planes in space
#
# **Visualize each task.** - Python, GeoGebra, Wolfram Alpha, ...
#
# * The plane passes through points $A(1, 2, 3)$, $B(3, 4, 5)$, and $C(2, 1, 4)$. Find the equation of the plane.
# * The plane passes through point $A(1, 2, 3)$ and is parallel to the plane $2x + 3y + 4z = 5$. Find the equation of the plane.
# * The plane passes through point $A(1, 2, 3)$ and is perpendicular to the normal vector $\vec{n} = [2, 3, 4]$. Find the equation of the plane.
# * We have two planes $2x + 3y + 4z = 5$ and $3x + 4y + 2z = 6$. Find the line of intersection of these planes.
# * Write the equation of the plane passing through point $A(1, 2, 3)$ and parallel to vectors $\vec{v_1} = [1, 0, 1]$ and $\vec{v_2} = [0, 1, -1]$.
# * We have the plane $2x + 3y + 4z = 5$. Find an example of a plane parallel and perpendicular to it.
# * We have the plane $2x + 3y + 4z = 5$ and point $A(1, 2, 3)$. Find the distance from point $A$ to this plane.
# * The plane intersects the coordinate axes at points $A(2, 0, 0)$, $B(0, 3, 0)$, and $C(0, 0, 4)$. Find the equation of the plane.
# * Calculate the angle between the plane $x + y + z = 1$ and the plane $x = 0$ (i.e., the $yz$ plane).
# * Find the vector perpendicular to the plane $x + y + z = 1$.

# %% [markdown]
# # Equations of Planes in Space: Concepts and Solutions
#
# ---
#
# ## **1. The plane passes through points $A(1, 2, 3)$, $B(3, 4, 5)$, and $C(2, 1, 4)$.**
#
# ### **Concept:**
# The equation of a plane passing through three points can be found using the cross product of two vectors formed by these points.
# The general equation of a plane is:
# $$
# ax + by + cz + d = 0
# $$
# Where $(a, b, c)$ is the normal vector of the plane.
#
# 1. **Find two vectors in the plane:**
#    $$ \vec{AB} = B - A = (3 - 1, 4 - 2, 5 - 3) = (2, 2, 2) $$
#    $$ \vec{AC} = C - A = (2 - 1, 1 - 2, 4 - 3) = (1, -1, 1) $$
#
# 2. **Find the normal vector:**
#    $$ \vec{n} = \vec{AB} \times \vec{AC} $$
#    $$ \vec{n} = \begin{vmatrix}
#    \mathbf{i} & \mathbf{j} & \mathbf{k} \\
#    2 & 2 & 2 \\
#    1 & -1 & 1
#    \end{vmatrix} = \mathbf{i}(2 - (-2)) - \mathbf{j}(2 - 2) + \mathbf{k}(-2 - 2) $$
#    $$ \vec{n} = (4, 0, -4) $$
#
# 3. **Substitute into the plane equation:**
#    $$ 4(x - 1) + 0(y - 2) - 4(z - 3) = 0 $$
#    $$ 4x - 4z - 4 = 0 \implies x - z = 1 $$
#
# **Equation:**
# $$ x - z = 1 $$
#
# ---
#
# ## **2. The plane passes through point $A(1, 2, 3)$ and is parallel to the plane $2x + 3y + 4z = 5$.**
#
# ### **Concept:**
# Parallel planes have the same normal vector.
# The equation of the plane is:
# $$
# 2x + 3y + 4z + d = 0
# $$
#
# 1. Substitute point $A(1, 2, 3)$:
#    $$ 2(1) + 3(2) + 4(3) + d = 0 $$
#    $$ 2 + 6 + 12 + d = 0 \implies d = -20 $$
#
# **Equation:**
# $$ 2x + 3y + 4z - 20 = 0 $$
#
# ---
#
# ## **3. The plane passes through point $A(1, 2, 3)$ and is perpendicular to the normal vector $\vec{n} = [2, 3, 4]$.**
#
# ### **Concept:**
# The equation of the plane is:
# $$
# 2x + 3y + 4z + d = 0
# $$
#
# 1. Substitute point $A(1, 2, 3)$:
#    $$ 2(1) + 3(2) + 4(3) + d = 0 $$
#    $$ 2 + 6 + 12 + d = 0 \implies d = -20 $$
#
# **Equation:**
# $$ 2x + 3y + 4z - 20 = 0 $$
#
# ---
#
# ## **4. Find the line of intersection of planes $2x + 3y + 4z = 5$ and $3x + 4y + 2z = 6$.**
#
# ### **Concept:**
# The line of intersection is parallel to the cross product of the normals of the planes.
#
# 1. **Normals:**
#    $$ \vec{n_1} = [2, 3, 4], \, \vec{n_2} = [3, 4, 2] $$
#    $$ \vec{d} = \vec{n_1} \times \vec{n_2} = \begin{vmatrix}
#    \mathbf{i} & \mathbf{j} & \mathbf{k} \\
#    2 & 3 & 4 \\
#    3 & 4 & 2
#    \end{vmatrix} = \mathbf{i}(-10 - 16) - \mathbf{j}(4 - 12) + \mathbf{k}(8 - 9) $$
#    $$ \vec{d} = [-26, 8, -1] $$
#
# 2. **Find a point on the line:**
#    Solve:
#    $$ 2x + 3y + 4z = 5 $$
#    $$ 3x + 4y + 2z = 6 $$
#    Set $z = 0$, solve:
#    $$ 2x + 3y = 5, \, 3x + 4y = 6 $$
#    $$ x = 2, \, y = -1 $$
#
# **Parametric Equation:**
# $$ x = 2 - 26t, \, y = -1 + 8t, \, z = -t $$
#
# ---
#
# ## **5. Plane passing through $A(1, 2, 3)$ parallel to vectors $\vec{v_1} = [1, 0, 1]$ and $\vec{v_2} = [0, 1, -1]$.**
#
# ### **Concept:**
# The normal vector is:
# $$
# \vec{n} = \vec{v_1} \times \vec{v_2} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# 1 & 0 & 1 \\
# 0 & 1 & -1
# \end{vmatrix} = \mathbf{i}(-1 - 1) - \mathbf{j}(1 - 0) + \mathbf{k}(1 - 0)
# $$
# $$
# \vec{n} = [-2, -1, 1]
# $$
#
# 1. Substitute into the plane equation:
#    $$ -2(x - 1) - (y - 2) + (z - 3) = 0 $$
#    $$ -2x - y + z + 5 = 0 $$
#
# **Equation:**
# $$ -2x - y + z + 5 = 0 $$
#
# ---
#
# ## **6. Example of parallel and perpendicular planes to $2x + 3y + 4z = 5$.**
#
# ### **Parallel Plane:**
# $$ 2x + 3y + 4z - 10 = 0 $$
#
# ### **Perpendicular Plane:**
# $$ 3x - 2y = 0 $$ (Example with orthogonal normal vectors)
#
# ---
#
# ## **7. Distance from point $A(1, 2, 3)$ to plane $2x + 3y + 4z = 5$.**
#
# ### **Concept:**
# Distance formula:
# $$
# d = \frac{|ax_1 + by_1 + cz_1 - d|}{\sqrt{a^2 + b^2 + c^2}}
# $$
# Substitute $a = 2$, $b = 3$, $c = 4$, $d = 5$, and $A(1, 2, 3)$:
# $$
# d = \frac{|2(1) + 3(2) + 4(3) - 5|}{\sqrt{2^2 + 3^2 + 4^2}}
# $$
# $$
# d = \frac{|2 + 6 + 12 - 5|}{\sqrt{4 + 9 + 16}} = \frac{15}{\sqrt{29}}
# $$
#
# ---
#
# ## **8. Plane intersects axes at $A(2, 0, 0)$, $B(0, 3, 0)$, $C(0, 0, 4)$.**
#
# ### **Concept:**
# Plane equation:
# $$
# \frac{x}{2} + \frac{y}{3} + \frac{z}{4} = 1
# $$
# Multiply through by 12:
# $$
# 6x + 4y + 3z = 12
# $$
#
# **Equation:**
# $$ 6x + 4y + 3z = 12 $$
#
# ---
#
# ## **9. Angle between planes $x + y + z = 1$ and $x = 0$.**
#
# ### **Concept:**
# Angle formula:
# $$
# \cos \theta = \frac{\vec{n_1} \cdot \vec{n_2}}{\|\vec{n_1}\| \|\vec{n_2}\|}
# $$
# Normals:
# $$
# \vec{n_1} = [1, 1, 1], \, \vec{n_2} = [1, 0, 0]
# $$
# $$
# \cos \theta = \frac{1}{\sqrt{3} \cdot 1} = \frac{1}{\sqrt{3}}
# $$
#
# ---
#
# ## **10. Vector perpendicular to plane $x + y + z = 1$.**
#
# ### **Concept:**
# The normal vector is the perpendicular vector:
# $$
# \vec{n} = [1, 1, 1]
# $$

# %% [markdown]
# ## **1.
#
# $$
# \vec{AB} = (2, 2, 2), \quad \vec{AC} = (1, -1, 1)
# $$
# $$
# \vec{n} = \vec{AB} \times \vec{AC} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# 2 & 2 & 2 \\
# 1 & -1 & 1
# \end{vmatrix} = (4, 0, -4)
# $$
# $$
# 4(x - 1) + 0(y - 2) - 4(z - 3) = 0
# $$
# $$
# x - z = 1
# $$
#
# ---
#
# ## **2.
#
# $$
# 2x + 3y + 4z + d = 0
# $$
# $$
# 2(1) + 3(2) + 4(3) + d = 0
# $$
# $$
# d = -20
# $$
# $$
# 2x + 3y + 4z - 20 = 0
# $$
#
# ---
#
# ## **3.
#
# $$
# 2x + 3y + 4z + d = 0
# $$
# $$
# 2(1) + 3(2) + 4(3) + d = 0
# $$
# $$
# d = -20
# $$
# $$
# 2x + 3y + 4z - 20 = 0
# $$
#
# ---
#
# ## **4.
#
# $$
# \vec{n_1} = [2, 3, 4], \quad \vec{n_2} = [3, 4, 2]
# $$
# $$
# \vec{d} = \vec{n_1} \times \vec{n_2} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# 2 & 3 & 4 \\
# 3 & 4 & 2
# \end{vmatrix} = [-26, 8, -1]
# $$
# $$
# 2x + 3y + 4z = 5, \quad 3x + 4y + 2z = 6
# $$
# $$
# z = 0 \implies 2x + 3y = 5, \quad 3x + 4y = 6
# $$
# $$
# x = 2, \quad y = -1
# $$
# $$
# x = 2 - 26t, \quad y = -1 + 8t, \quad z = -t
# $$
#
# ---
#
# ## **5.
#
# $$
# \vec{n} = \vec{v_1} \times \vec{v_2} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# 1 & 0 & 1 \\
# 0 & 1 & -1
# \end{vmatrix} = [-2, -1, 1]
# $$
# $$
# -2(x - 1) - (y - 2) + (z - 3) = 0
# $$
# $$
# -2x - y + z + 5 = 0
# $$
#
# ---
#
# ## **6.
#
# Parallel:
# $$
# 2x + 3y + 4z - 10 = 0
# $$
#
# Perpendicular:
# $$
# 3x - 2y = 0
# $$
#
# ---
#
# ## **7.
# $$
# d = \frac{|2(1) + 3(2) + 4(3) - 5|}{\sqrt{2^2 + 3^2 + 4^2}}
# $$
# $$
# d = \frac{|15|}{\sqrt{29}}
# $$
# $$
# d = \frac{15}{\sqrt{29}}
# $$
#
# ---
#
# ## **8.
#
# $$
# \frac{x}{2} + \frac{y}{3} + \frac{z}{4} = 1
# $$
# $$
# 6x + 4y + 3z = 12
# $$
#
# ---
#
# ## **9.
#
# $$
# \cos \theta = \frac{\vec{n_1} \cdot \vec{n_2}}{\|\vec{n_1}\| \|\vec{n_2}\|}
# $$
# $$
# \vec{n_1} = [1, 1, 1], \quad \vec{n_2} = [1, 0, 0]
# $$
# $$
# \cos \theta = \frac{1}{\sqrt{3} \cdot 1} = \frac{1}{\sqrt{3}}
# $$
#
# ---
#
# ## **10.
#
# $$
# \vec{n} = [1, 1, 1]
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create 3D figure
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Task 1: Plane through points A(1, 2, 3), B(3, 4, 5), and C(2, 1, 4)
Z1 = X - 1
ax.plot_surface(X, Y, Z1, alpha=0.5, color='blue', label="Plane: x - z = 1")

# Task 2: Plane through A(1, 2, 3), parallel to 2x + 3y + 4z = 5
Z2 = (20 - 2 * X - 3 * Y) / 4
ax.plot_surface(X, Y, Z2, alpha=0.5, color='green', label="Parallel to 2x + 3y + 4z = 5")

# Task 3: Plane through A(1, 2, 3), perpendicular to n = [2, 3, 4]
Z3 = (20 - 2 * X - 3 * Y) / 4
ax.plot_surface(X, Y, Z3, alpha=0.5, color='red', label="Perpendicular to n = [2, 3, 4]")

# Task 4: Line of intersection of two planes
Z4a = (5 - 2 * X - 3 * Y) / 4  # Plane 1
Z4b = (6 - 3 * X - 4 * Y) / 2  # Plane 2
ax.plot_surface(X, Y, Z4a, alpha=0.3, color='purple', label="2x + 3y + 4z = 5")
ax.plot_surface(X, Y, Z4b, alpha=0.3, color='orange', label="3x + 4y + 2z = 6")

# Task 8: Plane intersects axes at (2, 0, 0), (0, 3, 0), (0, 0, 4)
Z8 = (12 - 6 * X - 4 * Y) / 3
ax.plot_surface(X, Y, Z8, alpha=0.5, color='cyan', label="6x + 4y + 3z = 12")

# General plot configuration
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_xlim([-5, 5])
ax.set_ylim([-5, 5])
ax.set_zlim([-5, 5])
ax.grid()
plt.title("Visualization of Planes and Intersections")
plt.show()
